# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("C:/Users/91951/Downloads/Dataset/Dataset/data8/AgentLogingReport.csv")

# %%
df
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
# [1000 rows x 6 columns]

# %%
df.head()
# Out:
#    SL No               Agent       Date Login Time Logout Time  Duration
# 0      1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39  02:04:10
# 1      2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16  00:00:17
# 2      3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07  02:26:42
# 3      4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35  00:45:06
# 4      5              Mukesh  30-Jul-22   14:03:15    15:11:52  01:08:36

# %%
df.shape
# Out:
# (1000, 6)

# %%
df.describe()
# Out:
#              SL No
# count  1000.000000
# mean    500.500000
# std     288.819436
# min       1.000000
# 25%     250.750000
# 50%     500.500000
# 75%     750.250000
# max    1000.000000

# %%
df['date_data'] = pd.to_datetime(df['Date']).dt.day

# %%
df['month_data'] = pd.to_datetime(df['Date']).dt.month

# %%
df['year_date'] = pd.to_datetime(df['Date']).dt.year

# %%
df
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration  \
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
#      date_data  month_data  year_date
# ...

# %%
df.columns
# Out:
# Index(['SL No', 'Agent', 'Date', 'Login Time', 'Logout Time', 'Duration',
#        'date_data', 'month_data', 'year_date'],
#       dtype='object')

# %%
df.describe()
# Out:
#              SL No    date_data  month_data  year_date
# count  1000.000000  1000.000000      1000.0     1000.0
# mean    500.500000    24.894000         7.0     2022.0
# std     288.819436     3.156062         0.0        0.0
# min       1.000000     1.000000         7.0     2022.0
# 25%     250.750000    22.000000         7.0     2022.0
# 50%     500.500000    25.000000         7.0     2022.0
# 75%     750.250000    28.000000         7.0     2022.0
# max    1000.000000    30.000000         7.0     2022.0

# %%
df.isnull()
# Out:
#      SL No  Agent   Date  Login Time  Logout Time  Duration  date_data  \
# 0    False  False  False       False        False     False      False
# 1    False  False  False       False        False     False      False
# 2    False  False  False       False        False     False      False
# 3    False  False  False       False        False     False      False
# 4    False  False  False       False        False     False      False
# ..     ...    ...    ...         ...          ...       ...        ...
# 995  False  False  False       False        False     False      False
# 996  False  False  False       False        False     False      False
# 997  False  False  False       False        False     False      False
# 998  False  False  False       False        False     False      False
# 999  False  False  False       False        False     False      False
#
#      month_data  year_date
# 0         False      False
# 1         False      False
# 2         False      False
# ...

# %%
df.isnull().sum()
# Out:
# SL No          0
# Agent          0
# Date           0
# Login Time     0
# Logout Time    0
# Duration       0
# date_data      0
# month_data     0
# year_date      0
# dtype: int64

# %%
df.dtypes
# Out:
# SL No           int64
# Agent          object
# Date           object
# Login Time     object
# Logout Time    object
# Duration       object
# date_data       int64
# month_data      int64
# year_date       int64
# dtype: object

# %%
df.columns
# Out:
# Index(['SL No', 'Agent', 'Date', 'Login Time', 'Logout Time', 'Duration',
#        'date_data', 'month_data', 'year_date'],
#       dtype='object')

# %%
for i in df.columns:
    if df[i].dtypes == "O":
        print(i)
# Out:
# Agent
# Date
# Login Time
# Logout Time
# Duration

# %%
num_col = [i for i in df.columns if df[i].dtypes !="O"]

# %%
df[num_col]
# Out:
#      SL No  date_data  month_data  year_date
# 0        1         30           7       2022
# 1        2         30           7       2022
# 2        3         30           7       2022
# 3        4         30           7       2022
# 4        5         30           7       2022
# ..     ...        ...         ...        ...
# 995    996         20           7       2022
# 996    997         20           7       2022
# 997    998         20           7       2022
# 998    999         20           7       2022
# 999   1000          1           7       2022
#
# [1000 rows x 4 columns]

# %%
cat_val = [i for i in df.columns if df[i].dtypes == 'O']

# %%
df[cat_val]
# Out:
#                   Agent       Date Login Time Logout Time   Duration
# 0    Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2         Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3       Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4                Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..                  ...        ...        ...         ...        ...
# 995        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
# [1000 rows x 5 columns]

# %%
df.groupby('Date')

# %%
df.groupby('Date').count()
# Out:
#            SL No  Agent  Login Time  Logout Time  Duration  date_data  \
# Date
# 01-Jul-22      1      1           1            1         1          1
# 20-Jul-22     91     91          91           91        91         91
# 21-Jul-22     73     73          73           73        73         73
# 22-Jul-22    138    138         138          138       138        138
# 23-Jul-22     80     80          80           80        80         80
# 24-Jul-22     69     69          69           69        69         69
# 25-Jul-22     68     68          68           68        68         68
# 26-Jul-22     98     98          98           98        98         98
# 27-Jul-22    130    130         130          130       130        130
# 28-Jul-22     92     92          92           92        92         92
# 29-Jul-22    126    126         126          126       126        126
# 30-Jul-22     34     34          34           34        34         34
#
#            month_data  year_date
# Date
# ...

# %%
df.head()
# Out:
#    SL No               Agent       Date Login Time Logout Time  Duration  \
# 0      1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39  02:04:10
# 1      2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16  00:00:17
# 2      3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07  02:26:42
# 3      4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35  00:45:06
# 4      5              Mukesh  30-Jul-22   14:03:15    15:11:52  01:08:36
#
#    date_data  month_data  year_date
# 0         30           7       2022
# 1         30           7       2022
# 2         30           7       2022
# 3         30           7       2022
# 4         30           7       2022

# %%
df.groupby('date_data').count()
# Out:
#            SL No  Agent  Date  Login Time  Logout Time  Duration  month_data  \
# date_data
# 1              1      1     1           1            1         1           1
# 20            91     91    91          91           91        91          91
# 21            73     73    73          73           73        73          73
# 22           138    138   138         138          138       138         138
# 23            80     80    80          80           80        80          80
# 24            69     69    69          69           69        69          69
# 25            68     68    68          68           68        68          68
# 26            98     98    98          98           98        98          98
# 27           130    130   130         130          130       130         130
# 28            92     92    92          92           92        92          92
# 29           126    126   126         126          126       126         126
# ...

# %%
df.groupby('month_data').count()
# Out:
#             SL No  Agent  Date  Login Time  Logout Time  Duration  date_data  \
# month_data
# 7            1000   1000  1000        1000         1000      1000       1000
#
#             year_date
# month_data
# 7                1000

# %%
df1 = df.groupby('Agent').count()

# %%
df1.head()
# Out:
#                SL No  Date  Login Time  Logout Time  Duration  date_data  \
# Agent
# Aditya Shinde      1     1           1            1         1          1
# Aditya_iot         9     9           9            9         9          9
# Amersh             4     4           4            4         4          4
# Ameya Jain        10    10          10           10        10         10
# Ankitjha           4     4           4            4         4          4
#
#                month_data  year_date
# Agent
# Aditya Shinde           1          1
# Aditya_iot              9          9
# Amersh                  4          4
# Ameya Jain             10         10
# Ankitjha                4          4

# %%
df1.shape
# Out:
# (49, 8)

# %%
df.head()
# Out:
#    SL No               Agent       Date Login Time Logout Time  Duration  \
# 0      1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39  02:04:10
# 1      2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16  00:00:17
# 2      3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07  02:26:42
# 3      4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35  00:45:06
# 4      5              Mukesh  30-Jul-22   14:03:15    15:11:52  01:08:36
#
#    date_data  month_data  year_date
# 0         30           7       2022
# 1         30           7       2022
# 2         30           7       2022
# 3         30           7       2022
# 4         30           7       2022

# %%
sns.countplot(data=df, x='Login Time')
# Out:
# <Axes: xlabel='Login Time', ylabel='count'>

# %%
sns.countplot(data=df, x='Agent',width = 0.12)
# Out:
# <Axes: xlabel='Agent', ylabel='count'>

# %%
sns.boxplot(data=df, x='date_data')
# Out:
# <Axes: xlabel='date_data'>

# %%
df['date_data'].mean()
# Out:
# 24.894

# %% [markdown]
# # CONSIDERING OTHER DATASET

# %%
df = pd.read_csv('C:/Users/91951/Downloads/Dataset/Dataset/data1/Travel.csv')

# %%
df
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 4         200004          0   NaN     Self Enquiry         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
# ...

# %%
df.head()
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# ...

# %%
df.shape
# Out:
# (4888, 20)

# %%
df.dtypes
# Out:
# CustomerID                    int64
# ProdTaken                     int64
# Age                         float64
# TypeofContact                object
# CityTier                      int64
# DurationOfPitch             float64
# Occupation                   object
# Gender                       object
# NumberOfPersonVisiting        int64
# NumberOfFollowups           float64
# ProductPitched               object
# PreferredPropertyStar       float64
# MaritalStatus                object
# NumberOfTrips               float64
# Passport                      int64
# PitchSatisfactionScore        int64
# OwnCar                        int64
# NumberOfChildrenVisiting    float64
# Designation                  object
# MonthlyIncome               float64
# dtype: object

# %%
df.describe()
# Out:
#           CustomerID    ProdTaken          Age     CityTier  DurationOfPitch  \
# count    4888.000000  4888.000000  4662.000000  4888.000000      4637.000000
# mean   202443.500000     0.188216    37.622265     1.654255        15.490835
# std      1411.188388     0.390925     9.316387     0.916583         8.519643
# min    200000.000000     0.000000    18.000000     1.000000         5.000000
# 25%    201221.750000     0.000000    31.000000     1.000000         9.000000
# 50%    202443.500000     0.000000    36.000000     1.000000        13.000000
# 75%    203665.250000     0.000000    44.000000     3.000000        20.000000
# max    204887.000000     1.000000    61.000000     3.000000       127.000000
#
#        NumberOfPersonVisiting  NumberOfFollowups  PreferredPropertyStar  \
# count             4888.000000        4843.000000            4862.000000
# mean                 2.905074           3.708445               3.581037
# ...

# %%
df.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'TypeofContact', 'CityTier',
#        'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisiting',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
#        'OwnCar', 'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='object')

# %%
num_data = [i for i in df.columns if df[i].dtypes != 'O']

# %%
cat_data = [i for i in df.columns if df[i].dtypes == "O"]

# %%
num_data
# Out:
# ['CustomerID',
#  'ProdTaken',
#  'Age',
#  'CityTier',
#  'DurationOfPitch',
#  'NumberOfPersonVisiting',
#  'NumberOfFollowups',
#  'PreferredPropertyStar',
#  'NumberOfTrips',
#  'Passport',
#  'PitchSatisfactionScore',
#  'OwnCar',
#  'NumberOfChildrenVisiting',
#  'MonthlyIncome']

# %%
cat_data
# Out:
# ['TypeofContact',
#  'Occupation',
#  'Gender',
#  'ProductPitched',
#  'MaritalStatus',
#  'Designation']

# %%
df[num_data]
# Out:
#       CustomerID  ProdTaken   Age  CityTier  DurationOfPitch  \
# 0         200000          1  41.0         3              6.0
# 1         200001          0  49.0         1             14.0
# 2         200002          1  37.0         1              8.0
# 3         200003          0  33.0         1              9.0
# 4         200004          0   NaN         1              8.0
# ...          ...        ...   ...       ...              ...
# 4883      204883          1  49.0         3              9.0
# 4884      204884          1  28.0         1             31.0
# 4885      204885          1  52.0         3             17.0
# 4886      204886          1  19.0         3             16.0
# 4887      204887          1  36.0         1             14.0
#
#       NumberOfPersonVisiting  NumberOfFollowups  PreferredPropertyStar  \
# 0                          3                3.0                    3.0
# 1                          3                4.0                    4.0
# ...

# %%
df[cat_data]
# Out:
#         TypeofContact      Occupation  Gender ProductPitched MaritalStatus  \
# 0        Self Enquiry        Salaried  Female         Deluxe        Single
# 1     Company Invited        Salaried    Male         Deluxe      Divorced
# 2        Self Enquiry     Free Lancer    Male          Basic        Single
# 3     Company Invited        Salaried  Female          Basic      Divorced
# 4        Self Enquiry  Small Business    Male          Basic      Divorced
# ...               ...             ...     ...            ...           ...
# 4883     Self Enquiry  Small Business    Male         Deluxe     Unmarried
# 4884  Company Invited        Salaried    Male          Basic        Single
# 4885     Self Enquiry        Salaried  Female       Standard       Married
# 4886     Self Enquiry  Small Business    Male          Basic        Single
# 4887     Self Enquiry        Salaried    Male          Basic     Unmarried
#
#          Designation
# 0            Manager
# 1            Manager
# ...

# %%
df.isnull()
# Out:
#       CustomerID  ProdTaken    Age  TypeofContact  CityTier  DurationOfPitch  \
# 0          False      False  False          False     False            False
# 1          False      False  False          False     False            False
# 2          False      False  False          False     False            False
# 3          False      False  False          False     False            False
# 4          False      False   True          False     False            False
# ...          ...        ...    ...            ...       ...              ...
# 4883       False      False  False          False     False            False
# 4884       False      False  False          False     False            False
# 4885       False      False  False          False     False            False
# 4886       False      False  False          False     False            False
# 4887       False      False  False          False     False            False
#
# ...

# %%
df.isnull().count()
# Out:
# CustomerID                  4888
# ProdTaken                   4888
# Age                         4888
# TypeofContact               4888
# CityTier                    4888
# DurationOfPitch             4888
# Occupation                  4888
# Gender                      4888
# NumberOfPersonVisiting      4888
# NumberOfFollowups           4888
# ProductPitched              4888
# PreferredPropertyStar       4888
# MaritalStatus               4888
# NumberOfTrips               4888
# Passport                    4888
# PitchSatisfactionScore      4888
# OwnCar                      4888
# NumberOfChildrenVisiting    4888
# Designation                 4888
# MonthlyIncome               4888
# dtype: int64

# %%
#Here we can find no missing values

# %%
df.groupby('Gender').count()
# Out:
#          CustomerID  ProdTaken   Age  TypeofContact  CityTier  \
# Gender
# Fe Male         155        155   155            155       155
# Female         1817       1817  1735           1807      1817
# Male           2916       2916  2772           2901      2916
#
#          DurationOfPitch  Occupation  NumberOfPersonVisiting  \
# Gender
# Fe Male              155         155                     155
# Female              1707        1817                    1817
# Male                2775        2916                    2916
#
#          NumberOfFollowups  ProductPitched  PreferredPropertyStar  \
# Gender
# Fe Male                155             155                    155
# Female                1800            1817                   1805
# Male                  2888            2916                   2902
#
#          MaritalStatus  NumberOfTrips  Passport  PitchSatisfactionScore  \
# Gender
# Fe Male            155            155       155                     155
# ...

# %%
sns.countplot(data = df, x="Gender")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
#Three different categories of gender is present in the data

# %%
df.head()
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# ...

# %%
df.groupby('CustomerID').count()
# Out:
#             ProdTaken  Age  TypeofContact  CityTier  DurationOfPitch  \
# CustomerID
# 200000              1    1              1         1                1
# 200001              1    1              1         1                1
# 200002              1    1              1         1                1
# 200003              1    1              1         1                1
# 200004              1    0              1         1                1
# ...               ...  ...            ...       ...              ...
# 204883              1    1              1         1                1
# 204884              1    1              1         1                1
# 204885              1    1              1         1                1
# 204886              1    1              1         1                1
# 204887              1    1              1         1                1
#
#             Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# CustomerID
# ...

# %%
#we can conclude that customer ID's are unique

# %%
df.groupby('Occupation').count()
# Out:
#                 CustomerID  ProdTaken   Age  TypeofContact  CityTier  \
# Occupation
# Free Lancer              2          2     2              2         2
# Large Business         434        434   414            434       434
# Salaried              2368       2368  2254           2363      2368
# Small Business        2084       2084  1992           2064      2084
#
#                 DurationOfPitch  Gender  NumberOfPersonVisiting  \
# Occupation
# Free Lancer                   2       2                       2
# Large Business              412     434                     434
# Salaried                   2263    2368                    2368
# Small Business             1960    2084                    2084
#
#                 NumberOfFollowups  ProductPitched  PreferredPropertyStar  \
# Occupation
# Free Lancer                     2               2                      2
# Large Business                432             434                    432
# ...

# %%
sns.scatterplot(data = df, x='Occupation', y='Gender')
# Out:
# <Axes: xlabel='Occupation', ylabel='Gender'>

# %%
sns.pairplot(df,size = 10)

# %%
df.head()
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# ...

# %%
sns.lmplot(x='Passport',y='OwnCar',data=df,hue = "Designation")

# %%
sns.catplot(data=df, x= 'Designation', y='MonthlyIncome',hue = "MaritalStatus")

# %%
df.groupby("MaritalStatus").count()
# Out:
#                CustomerID  ProdTaken   Age  TypeofContact  CityTier  \
# MaritalStatus
# Divorced              950        950   905            944       950
# Married              2340       2340  2241           2325      2340
# Single                916        916   834            912       916
# Unmarried             682        682   682            682       682
#
#                DurationOfPitch  Occupation  Gender  NumberOfPersonVisiting  \
# MaritalStatus
# Divorced                   898         950     950                     950
# Married                   2232        2340    2340                    2340
# Single                     825         916     916                     916
# Unmarried                  682         682     682                     682
#
#                NumberOfFollowups  ProductPitched  PreferredPropertyStar  \
# MaritalStatus
# Divorced                     945             950                    944
# ...

# %%
df['MonthlyIncome'].mean()
# Out:
# 23619.85349087003

# %%
sns.boxplot(data=df, y = "MonthlyIncome")
# Out:
# <Axes: ylabel='MonthlyIncome'>

# %%
#FINDING THE OUTLIERS

# %%
q1 = df['MonthlyIncome'].quantile(0.25)

# %%
q1
# Out:
# 20346.0

# %%
q3 = df['MonthlyIncome'].quantile(0.75)

# %%
q3
# Out:
# 25571.0

# %%
IQR = q3 - q1

# %%
IQRdf
# Out:
# 5225.0

# %%
lower_fence = q1 - (1.5*IQR)

# %%
lower_fence
# Out:
# 12508.5

# %%
Upper_fence = q3 + (1.5*IQR)

# %%
Upper_fence
# Out:
# 33408.5

# %%
df[['MonthlyIncome']]
# Out:
#       MonthlyIncome
# 0           20993.0
# 1           20130.0
# 2           17090.0
# 3           17909.0
# 4           18468.0
# ...             ...
# 4883        26576.0
# 4884        21212.0
# 4885        31820.0
# 4886        20289.0
# 4887        24041.0
#
# [4888 rows x 1 columns]

# %%
upper_values =df[df['MonthlyIncome'] < lower_fence]

# %%
df[df['MonthlyIncome'] > Upper_fence]
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 25        200025          0  53.0     Self Enquiry         1             11.0
# 29        200029          0  46.0     Self Enquiry         3              8.0
# 38        200038          0  36.0     Self Enquiry         1             11.0
# 45        200045          1  41.0     Self Enquiry         1             18.0
# 62        200062          0  50.0     Self Enquiry         1             13.0
# ...          ...        ...   ...              ...       ...              ...
# 4851      204851          1  40.0     Self Enquiry         1              9.0
# 4859      204859          1  51.0  Company Invited         3             19.0
# 4868      204868          1  43.0  Company Invited         2             15.0
# 4869      204869          1  56.0     Self Enquiry         3             16.0
# 4870      204870          1  57.0     Self Enquiry         3             23.0
#
# ...

# %% [markdown]
# # Dropping of the outliers

# %%
upper_array = np.where(df['MonthlyIncome'] > Upper_fence)[0]
#creating of array for accessing of the indexes 
#and then creating of an 1-d array by placing [0]

# %%
upper_array
# Out:
# array([  25,   29,   38,   45,   62,  105,  123,  165,  186,  187,  190,
#         231,  233,  237,  244,  257,  270,  279,  290,  326,  392,  400,
#         411,  473,  497,  535,  538,  568,  584,  595,  716,  746,  749,
#         766,  770,  814,  851,  858,  869,  898,  899,  913,  916,  918,
#         922,  955,  956, 1009, 1116, 1126, 1129, 1140, 1154, 1242, 1264,
#        1277, 1330, 1331, 1377, 1401, 1437, 1443, 1495, 1499, 1515, 1532,
#        1575, 1593, 1635, 1656, 1657, 1660, 1701, 1703, 1707, 1714, 1727,
#        1740, 1749, 1760, 1796, 1862, 1870, 1881, 1943, 1967, 2005, 2008,
#        2038, 2054, 2065, 2186, 2216, 2219, 2236, 2240, 2284, 2321, 2328,
#        2339, 2368, 2369, 2383, 2386, 2388, 2392, 2425, 2426, 2462, 2469,
#        2473, 2482, 2489, 2506, 2509, 2549, 2550, 2556, 2563, 2567, 2591,
#        2609, 2630, 2631, 2634, 2638, 2675, 2677, 2679, 2681, 2688, 2701,
#        2707, 2714, 2723, 2724, 2734, 2744, 2758, 2770, 2773, 2792, 2823,
# ...

# %%
df.drop(index = upper_array,inplace = True)

# %%
df
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 4         200004          0   NaN     Self Enquiry         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
# ...

# %%
Lower_array = np.where(df['MonthlyIncome'] < lower_fence)[0]

# %%
Lower_array
# Out:
# array([ 135, 2466], dtype=int64)

# %%
df.drop(index=Lower_array,inplace = True)

# %%
df
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 4         200004          0   NaN     Self Enquiry         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
# ...

# %%
df.shape
# Out:
# (4543, 20)

# %%
#We can see the change in shape of the data Frame

# %%
df.head()
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# ...

# %% [markdown]
# # Replacing of Null Values

# %%
df['Age'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 4883    False
# 4884    False
# 4885    False
# 4886    False
# 4887    False
# Name: Age, Length: 4543, dtype: bool

# %%
df['Age'].isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 4883    False
# 4884    False
# 4885    False
# 4886    False
# 4887    False
# Name: Age, Length: 4543, dtype: bool

# %%
null_values = np.where(df['Age'].isna())[0]

# %%
null_values
# Out:
# array([   4,   11,   19,   20,   21,   25,   41,   47,   50,   53,   64,
#          83,   92,  132,  133,  171,  174,  183,  190,  223,  224,  232,
#         242,  247,  250,  278,  303,  313,  316,  343,  352,  368,  370,
#         382,  407,  412,  419,  420,  425,  456,  458,  463,  471,  492,
#         511,  515,  537,  552,  582,  587,  588,  592,  603,  608,  635,
#         645,  660,  681,  686,  687,  693,  694,  708,  722,  732,  745,
#         747,  752,  760,  785,  804,  824,  826,  834,  846,  853,  858,
#         878,  883,  894,  897,  909,  912,  917,  943,  947,  950,  953,
#         956,  971,  973,  976,  980,  983,  987,  997, 1001, 1016, 1017,
#        1036, 1049, 1064, 1070, 1078, 1096, 1103, 1109, 1114, 1115, 1134,
#        1147, 1153, 1154, 1172, 1173, 1176, 1193, 1211, 1213, 1216, 1220,
#        1223, 1229, 1234, 1235, 1250, 1261, 1268, 1271, 1276, 1282, 1288,
#        1301, 1333, 1351, 1352, 1362, 1368, 1373, 1396, 1397, 1411, 1418,
# ...

# %%
df_mean= df['Age'].mean()

# %%
#Relace the null values with the mean of the column

# %%
df['Age'].fillna(value = df_mean,inplace = True)

# %%
df
# Out:
#       CustomerID  ProdTaken        Age    TypeofContact  CityTier  \
# 0         200000          1  36.783414     Self Enquiry         3
# 1         200001          0  49.000000  Company Invited         1
# 2         200002          1  37.000000     Self Enquiry         1
# 3         200003          0  33.000000  Company Invited         1
# 4         200004          0  36.783414     Self Enquiry         1
# ...          ...        ...        ...              ...       ...
# 4883      204883          1  49.000000     Self Enquiry         3
# 4884      204884          1  28.000000  Company Invited         1
# 4885      204885          1  52.000000     Self Enquiry         3
# 4886      204886          1  36.783414     Self Enquiry         3
# 4887      204887          1  36.000000     Self Enquiry         1
#
#       DurationOfPitch      Occupation  Gender  NumberOfPersonVisiting  \
# 0                 6.0        Salaried  Female                3.000000
# ...

# %%
df['Age'].mean()
# Out:
# 36.73566125986042

# %%
#here we can see that the mean of the column is same as before, But null values are been replaced by Mean Of the column
